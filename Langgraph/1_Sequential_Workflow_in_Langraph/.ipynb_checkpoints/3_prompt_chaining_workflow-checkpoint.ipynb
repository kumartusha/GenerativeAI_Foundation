# %% [markdown]
# # Create the Blog Generator workflow

# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()

# %%
# model.invoke("what is the criteria for clearing the JEE Exam").content

# %%
# Create a State
class BlogState(TypedDict):
    title: str
    outline: str
    content: str
    score: str

# %%
def get_gen_outline(state: BlogState) -> BlogState:
    # Get the title.
    title = state['title']

    # Prompt for the topic
    prompt = f'Give me the detailed report about {title}'

    # Get the answer
    answer = model.invoke(prompt).content

    # Update the state
    state['outline'] = answer

    # Return the state
    return state

# %%
def get_gen_blog(state: BlogState) ->  BlogState:
    # get the detailed outline of the topic.
    title = state['title']
    outline = state['outline']

    # Prompt for generating the blog
    prompt = f'Write a detailed blog on the title - {title} using the following outline \n {outline}'

    # Get the answer
    answer = model.invoke(prompt).content

    # Update the state
    state['content'] = answer

    # Return the state
    return state

# %%
def get_score(state: BlogState) -> BlogState:
    # get the score from the state.
    # score = state['score']
    content = state['content']
    outline = state['outline']

    # Prompt for generating the score.
    prompt = f"Evaluate my blog {content} based on the {outline} and return an integer score from 1 to 10 only."

    #Call the LLM.
    answer = model.invoke(prompt).content

    # Update the state
    state['score'] = answer

    # Return the state
    return state

# %%
# Initialize the graph
graph = StateGraph(BlogState)


# Add nodes to the graph
graph.add_node('gen_outline', get_gen_outline)
graph.add_node('gen_blog', get_gen_blog)
graph.add_node('score_calculate', get_score)

# Add edges
graph.add_edge(START, 'gen_outline')
graph.add_edge('gen_outline', 'gen_blog')
graph.add_edge('gen_blog', 'score_calculate')
graph.add_edge('score_calculate', END)

# Compile the graph
graph.compile()

# %%
workflow = graph.compile()

# %%
# Execute the graph flow.

initial_state = {"title": "HFT Arbitrage"}


final_output = workflow.invoke(initial_state)

print(final_output['content'])
# Out:
# Despite the controversy surrounding HFT arbitrage, there are several advantages to this strategy. Firstly, HFT arbitrage provides liquidity to the market, ensuring that there are always buyers and sellers for financial instruments. This can help to reduce transaction costs for investors and improve market efficiency.
#
# Additionally, HFT arbitrage can help to narrow bid-ask spreads, making it easier for investors to buy and sell assets at fair prices. By quickly identifying and exploiting price discrepancies, HFT arbitrage can also help to keep market prices in line with fundamental values.
#
# Furthermore, HFT arbitrage can lead to improved price discovery and increased market efficiency. By quickly reacting to new information and price movements, HFT arbitrageurs can help to incorporate new information into asset prices more rapidly, allowing the market to more accurately reflect supply and demand dynamics.
#
# In conclusion, HFT arbitrage is a high-speed trading strategy that involves capitalizing on price discrepancies between financial instruments using sophisticated algorithms. While controversial, HFT arbitrage can provide liquidity to the market, narrow bid-ask spreads, improve price discovery, and enhance market efficiency. However, regulators must continue to monitor and regulate HFT arbitrage to prevent market manipulation and protect individual investors.

# %%
workflow.invoke(initial_state)
# Out:
# {'title': 'HFT Arbitrage',
#  'outline': 'High Frequency Trading (HFT) Arbitrage is a strategy in which traders use advanced computer algorithms to exploit small price differences in financial assets across different markets. This strategy takes advantage of the high speed at which these algorithms can execute trades, allowing traders to capture profits in a matter of milliseconds.\n\nThere are several types of HFT arbitrage strategies, including:\n\n1. Statistical arbitrage: This strategy involves identifying patterns and correlations in asset prices and executing trades based on statistical models to profit from small price discrepancies.\n\n2. Market-making: Traders using this strategy place bids and offers in the market and profit from the spread between the buying and selling prices of an asset.\n\n3. Liquidity-providing arbitrage: This strategy involves taking advantage of differences in liquidity across different markets by buying assets where liquidity is high and selling them where it is low.\n\nHFT arbitrage is controversial because it can create market instability and lead to market manipulation. Critics argue that HFT traders have an unfair advantage over traditional traders due to their high-speed trading capabilities.\n\nRegulators have implemented measures to curb the impact of HFT arbitrage on financial markets, such as imposing minimum resting times for orders or implementing circuit breakers to prevent rapid price movements.\n\nOverall, HFT arbitrage is a complex and highly technical trading strategy that requires advanced technology and sophisticated algorithms to execute. While it can generate significant profits for those who employ it effectively, it also carries inherent risks and regulatory challenges.',
#  'content': '\n\nHFT arbitrage, or High Frequency Trading arbitrage, is a trading strategy that has gained significant attention in the financial industry in recent years. This strategy involves using advanced computer algorithms to exploit small price differences in financial assets across different markets. These algorithms are able to execute trades at incredibly high speeds, often in just milliseconds, allowing traders to capitalize on these small price discrepancies.\n\nOne of the key types of HFT arbitrage strategies is statistical arbitrage. This strategy involves using statistical models to identify patterns and correlations in asset prices. By analyzing historical data and market trends, traders can identify opportunities to profit from small price discrepancies. For example, if two similar assets are trading at slightly different prices in different markets, an HFT trader can quickly buy the cheaper asset and sell the more expensive one, capturing a profit in the process.\n\nAnother common type of HFT arbitrage strategy is market-making. Market-making involves placing bids and offers in the market, acting as a liquidity provider. By placing bids to buy and offers to sell, traders can profit from the spread between the buying and selling prices of an asset. Market-makers play a crucial role in ensuring liquidity in the market, but they also have the potential to profit from small price discrepancies using their high-speed trading capabilities.\n\nIn addition to statistical arbitrage and market-making, HFT traders also utilize liquidity-providing arbitrage strategies. This strategy involves taking advantage of differences in liquidity across different markets. By buying assets in markets where liquidity is high and selling them in markets where it is low, traders can profit from these discrepancies. This type of arbitrage requires a deep understanding of market dynamics and liquidity patterns to execute effectively.\n\nHowever, despite its potential for profit, HFT arbitrage is not without its controversies. Critics argue that HFT traders have an unfair advantage over traditional traders due to their high-speed trading capabilities. This can lead to market instability and create opportunities for market manipulation. Regulators have implemented measures to address these concerns, such as imposing minimum resting times for orders or implementing circuit breakers to prevent rapid price movements.\n\nOverall, HFT arbitrage is a complex and highly technical trading strategy that requires advanced technology and sophisticated algorithms to execute. While it can generate significant profits for those who employ it effectively, it also carries inherent risks and regulatory challenges. Traders must be aware of these risks and ensure they have the necessary technology and expertise to navigate the complexities of HFT arbitrage successfully.',
#  'score': 'I would rate your blog a 8. It provides a clear explanation of HFT arbitrage strategies, discusses the controversies surrounding it, and highlights the potential risks and challenges associated with this trading strategy. It could benefit from providing some real-life examples or case studies to further illustrate the concepts discussed.'}
