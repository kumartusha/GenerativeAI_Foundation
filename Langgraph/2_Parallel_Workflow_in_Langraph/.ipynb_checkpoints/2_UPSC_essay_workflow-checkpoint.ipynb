# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from typing import TypedDict

# For structured Output.
from pydantic import BaseModel, Field

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model='gpt-4o-mini')

# %%
# model.invoke("Hello How are you buddy")

# %%
# Create the schema using the pydantic for structured Output.
class EvaluationSchema(BaseModel):
    feedback: str =  Field(description='Detailed feedback for the essay')
    score: int = Field(description='Score out of 10')

# %%
# Getting the structured output.
structured_model = model.with_structured_output(EvaluationSchema)
# Out:
# RunnableBinding(bound=ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x12b142510>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x12b142f90>, root_client=<openai.OpenAI object at 0x12b1402f0>, root_async_client=<openai.AsyncOpenAI object at 0x12b142cf0>, model_name='gpt-4o-mini', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True), kwargs={'response_format': <class '__main__.EvaluationSchema'>, 'ls_structured_output_format': {'kwargs': {'method': 'json_schema', 'strict': None}, 'schema': {'type': 'function', 'function': {'name': 'EvaluationSchema', 'description': '', 'parameters': {'properties': {'feedback': {'description': 'Detailed feedback for the essay', 'type': 'string'}, 'score': {'description': 'Score out of 10', 'type': 'integer'}}, 'required': ['feedback', 'score'], 'type': 'object'}}}}}, config={}, config_factories=[])
# | RunnableBinding(bound=RunnableLambda(...), kwargs={}, config={}, config_factories=[], custom_output_type=<class '__main__.EvaluationSchema'>)

# %%
essay = """"""
