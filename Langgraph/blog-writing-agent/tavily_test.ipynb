# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
tool = TavilySearchResults(max_results=2)
results = tool.invoke({"query": 'ChatGPT version releases and updates from 2022 to 2026'})
results
# Out:
# [{'title': 'ChatGPT New Features 2026: GPT-5.4, Codex & Updates',
#   'url': 'https://aibusinessweekly.net/p/chatgpt-new-features-2026',
#   'content': "Misconception 1: ChatGPT still runs on GPT-4. GPT-4 and GPT-4o are no longer the current models. ChatGPT runs on the GPT-5 family - GPT-5 launched August 2025, with iterative updates through GPT-5.4 as of March 2026. GPT-5.1 models were deprecated on March 11, 2026, with existing conversations automatically routed to GPT-5.3 or GPT-5.4 equivalents. Anyone comparing ChatGPT to competitors using GPT-4-era benchmarks or experiences is comparing against a product that no longer exists. [...] Misconception 2: The model names indicate major discontinuous releases. GPT-5.1, 5.2, 5.3, 5.4 are iterative improvements within the GPT-5 family, not entirely different products. Each iteration improves specific capabilities - better instruction following, improved tone, stronger coding, faster reasoning - without fundamentally changing how you use the platform. The naming cadence reflects OpenAI's shift toward continuous model improvement rather than discrete annual releases. [...] What ChatGPT model is available in 2026? ChatGPT currently runs on the GPT-5 model family as of March 2026. The active models are GPT-5.4 Thinking (frontier reasoning model, shows upfront thinking plan), GPT-5.4 mini (cost-efficient reasoning fallback), GPT-5.3 Instant (everyday tasks), and GPT-5.3 Codex (agentic coding). GPT-5.1 models were deprecated on March 11, 2026. The separate o3 and o4-mini reasoning models continue to exist for specialized high-compute tasks. GPT-4 and GPT-4o are no longer the current models.",
#   'score': 0.9998746},
#  {'title': 'Objects',
#   'url': 'https://objects.ws/blog/chatgpt-version-history/',
#   'content': 'GPT-4 Release March 2023 This release prioritized multimodal capabilities. GPT-3.5 accepted only text input. But, GPT-4 could process image and text input, enabling it to be multimodal.\nPerformance Update December 2022 ChatGPT introduced a major update that improved usability and response times.\nChatGPT Launch November 2022 ChatGPT began its journey and launched significant advancements in NLP (Natural Language Processing). [...] ChatGPT VersionsRelease DateCrucial Features\nChatGPT 5.5 April 2026 The latest version prioritizes reasoning, agentic coding, deep research, and computer use (autonomous navigation of interfaces).\nChatGPT 5.4 March 2026 This version valued reasoning, agentic workflows, and coding. Users were able to perform crucial tasks, such as deep web search. Moreover, it helped maintain context more effectively for queries that usually required detailed thinking.\nChatGPT 5.3 GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was introduced in March 2026.This version was handy for enhancing full-cycle software development along with collaboration. It also delighted users through more accurate, logical answers. [...] OpenAI Plans to Completely Replace GPT-4 with GPT-4o April 2025 Users performed writing and coding activities smartly. Users’ prompts were adequately followed.\nOpenAI GPT-4.5 Release to ChatGPT Pro Subscribers February 2025 This version prioritized world knowledge and efficiently comprehended user intent.\nOpenAI o3-mini Launch January 2025 This model helped enhance small-model capabilities, particularly in STEM fields such as coding, science, and math.\nIntroducing OpenAI Operator Agent January 2025 The agent benefited from GPT-4’s vision and reasoning capabilities to enhance interactions with web pages.\nScheduled Tasks in ChatGPT January 2025 This update helped automate schedule tasks. Users could configure notifications, daily reports, and AI-generated messages.',
#   'score': 0.9996345}]

# %%
for r in results:
    print(r['content'])
# Out:
# Misconception 1: ChatGPT still runs on GPT-4. GPT-4 and GPT-4o are no longer the current models. ChatGPT runs on the GPT-5 family - GPT-5 launched August 2025, with iterative updates through GPT-5.4 as of March 2026. GPT-5.1 models were deprecated on March 11, 2026, with existing conversations automatically routed to GPT-5.3 or GPT-5.4 equivalents. Anyone comparing ChatGPT to competitors using GPT-4-era benchmarks or experiences is comparing against a product that no longer exists. [...] Misconception 2: The model names indicate major discontinuous releases. GPT-5.1, 5.2, 5.3, 5.4 are iterative improvements within the GPT-5 family, not entirely different products. Each iteration improves specific capabilities - better instruction following, improved tone, stronger coding, faster reasoning - without fundamentally changing how you use the platform. The naming cadence reflects OpenAI's shift toward continuous model improvement rather than discrete annual releases. [...] What ChatGPT model is available in 2026? ChatGPT currently runs on the GPT-5 model family as of March 2026. The active models are GPT-5.4 Thinking (frontier reasoning model, shows upfront thinking plan), GPT-5.4 mini (cost-efficient reasoning fallback), GPT-5.3 Instant (everyday tasks), and GPT-5.3 Codex (agentic coding). GPT-5.1 models were deprecated on March 11, 2026. The separate o3 and o4-mini reasoning models continue to exist for specialized high-compute tasks. GPT-4 and GPT-4o are no longer the current models.
# GPT-4 Release March 2023 This release prioritized multimodal capabilities. GPT-3.5 accepted only text input. But, GPT-4 could process image and text input, enabling it to be multimodal.
# Performance Update December 2022 ChatGPT introduced a major update that improved usability and response times.
# ChatGPT Launch November 2022 ChatGPT began its journey and launched significant advancements in NLP (Natural Language Processing). [...] ChatGPT VersionsRelease DateCrucial Features
# ChatGPT 5.5 April 2026 The latest version prioritizes reasoning, agentic coding, deep research, and computer use (autonomous navigation of interfaces).
# ChatGPT 5.4 March 2026 This version valued reasoning, agentic workflows, and coding. Users were able to perform crucial tasks, such as deep web search. Moreover, it helped maintain context more effectively for queries that usually required detailed thinking.
# ChatGPT 5.3 GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was introduced in March 2026.This version was handy for enhancing full-cycle software development along with collaboration. It also delighted users through more accurate, logical answers. [...] OpenAI Plans to Completely Replace GPT-4 with GPT-4o April 2025 Users performed writing and coding activities smartly. Users’ prompts were adequately followed.
# OpenAI GPT-4.5 Release to ChatGPT Pro Subscribers February 2025 This version prioritized world knowledge and efficiently comprehended user intent.
# OpenAI o3-mini Launch January 2025 This model helped enhance small-model capabilities, particularly in STEM fields such as coding, science, and math.
# Introducing OpenAI Operator Agent January 2025 The agent benefited from GPT-4’s vision and reasoning capabilities to enhance interactions with web pages.
# Scheduled Tasks in ChatGPT January 2025 This update helped automate schedule tasks. Users could configure notifications, daily reports, and AI-generated messages.
