# %%
# !pip install -q langchain-openai langchain-core requests

# %%
# tool Create

@tool
def get_conversion_factor(base_currency: str, target_currency: str) -> float:
    """
    This function fetches the currency conversion factor between a given base currency and a target currency
    """
    url = f'https://v6.exchangerate-api.com/v6/df7745014d40b1725e358ee7/pair/{base_currency}/{target_currency}'

    response = requests.get(url)

    return response.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # tool Create
# ----> 3 @tool
#       4 def get_conversion_factor(base_currency: str, target_currency: str) -> float:
#       5     """
#       6     This function fetches the currency conversion factor between a given base currency and a target currency
#       7     """
#       8     url = f'https://v6.exchangerate-api.com/v6/df7745014d40b1725e358ee7/pair/{base_currency}/{target_currency}'
#
# NameError: name 'tool' is not defined
