# %%
# !pip install -q langchain-openai langchain-core requests
from langchain_core.tools import tool

# %%
# tool Create

@tool
def get_conversion_factor(base_currency: str, target_currency: str) -> float:
    """
    This function fetches the currency conversion factor between a given base currency and a target currency
    """
    url = f'https://v6.exchangerate-api.com/v6/df7745014d40b1725e358ee7/pair/{base_currency}/{target_currency}'

    response = requests.get(url)

    return response.json()

# %%
final_func = get_conversion_factor.invoke({"base_currency": "usd", "target_currency": "eur"})

# %%
final_func
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1765411202,
#  'time_last_update_utc': 'Thu, 11 Dec 2025 00:00:02 +0000',
#  'time_next_update_unix': 1765497602,
#  'time_next_update_utc': 'Fri, 12 Dec 2025 00:00:02 +0000',
#  'base_code': 'USD',
#  'target_code': 'EUR',
#  'conversion_rate': 0.8573}

# %%
final_func["conversion_rate"]
# Out:
# 0.8573
